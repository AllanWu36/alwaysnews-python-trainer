# %% [markdown]
# ### 如何翻墙
#
# 如果你想成为一个合格的程序员，那翻墙一定是没有写在课程列表里的，却又是最重要的必备技能之一。
#
# 但其实真的达成翻墙目标没有大家想象的那么复杂，只需要付费，下载app，开启服务就可以，pc 、手机都行。
#
# 唯一可能比较麻烦的是选择一个安全可靠的服务商，因为这种生意在国内都见不得人，稳定性也比较难有保障，很多那种充钱跑路的，我朋友也遇到过几次。

# %% [markdown]
# 这里我介绍一下我自己一直在用的方法，质量不一定最好，但优势是便宜和不跑路（最起码4、5年没跑了）：
#
# 首先在[这里](https://www.qwqjsq8.com/auth/register?code=yqYsC4zo94webVVKaKHlMRDUapw1F96s)进行注册，默认会填写邀请码，后续你付费后，我会有10%的返利，如果你觉得不想便宜我，你删除就行了。
#
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# 注册完毕登录后，你可以先去看看你适合什么套餐，初次上路的建议购买最小的月租套餐，因为一个是刚开始需求没那么大，二是就算商家跑路了，损失也很小
#
# <div>
# <img src="attachment:shop.png" width="800"/>
# </div>

# %% [markdown]
#  然后根据你选择的套餐进行充值，目前只支持支付宝
#
# <div>
# <img src="attachment:image.png" width="800"/>
# </div>

# %% [markdown]
# 充值成功后，返回商店页面点击购买，一路确定即可
#
# <div>
# <img src="attachment:image.png" width="300"/>
# </div>

# %% [markdown]
# 购买成功，去下载页面下载对应平台的服务程序，可以去教程区看看，根据教程操作完毕后，就可以畅游互联网了。
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Windows clash工具介绍

# %% [markdown]
# 一般用户基本都是用Windows操作系统，所以用到的翻墙工具肯定都是Clash。
#
# 介绍下工具——Clash,安装后进入General界面，选择System Proxy即可开始运行软件。其中Start With Windows/macOS代表开机后自动运行。
#
# *不同版本和主题的客户端按钮分布位置可能略有不同，请参考下图示例。
#
# <div>
# <img src="attachment:image.png" width="750"/>
# </div>
#
# 下载并成功启动clash后，在教程里点击一键导入，如果不出意外，这时候你的clash就添加了一系列的翻墙节点配置。
#
# <div>
# <img src="attachment:image-3.png" width="750"/>
# </div>
#
# 如果自动配置无效，可以试下手动复制配置地址，然后在clash里手动导入
# <div>
# <img src="attachment:image-2.png" width="750"/>
# </div>
#
#
# 导入翻墙节点成功后，可以从clash打开节点列表，查看状态，并修改路由的规则：
# <div>
# <img src="attachment:image-5.png" width="750"/>
# </div>
#
# Clash 共有三种工作模式：
#
#  - 全局（Global）：所有请求直接发往代理服务器
#  - 规则（Rule）：所有请求根据配置文件规则进行分流
#  - 直连（Direct）：所有请求直接发往目的地
#
# ### 更加详细的说明，可以看[文档](https://docs.cfw.lbyczf.com/)

# %% [markdown]
# 最后，如果你还有任何疑问，可以在群里讨论，我会尽我所能一一解答。
